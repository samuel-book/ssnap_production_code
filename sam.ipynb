# %% [markdown]
# ## SAMueL Production Code

# %% [markdown]
# ## Set up SAMueL instance

# %%
from main import Samuel
sam = Samuel(minimum_admissions_per_year=100)

# %% [markdown]
# ## Show loaded data

# %%
sam.globvars.original_data.head()
# Out:
#                                          stroke team   age  male  infarction  \
# 0  Northumbria Specialist Emergency Care Hospital...  77.5     1           1
# 1  Northumbria Specialist Emergency Care Hospital...  72.5     0           1
# 2                              West Suffolk Hospital  87.5     0           0
# 3                              West Suffolk Hospital  72.5     0           1
# 4                           Royal Victoria Infirmary  77.5     1           1
#
#    onset-to-arrival time  onset known  precise onset known  \
# 0                   3033            1                    0
# 1                   5395            0                    0
# 2                    713            0                    0
# 3                    278            1                    1
# 4                    170            1                    1
#
#    onset during sleep  arrive by ambulance  call-to-ambulance-arrival time  \
# ...

# %%
sam.globvars.included_teams
# Out:
# ["Addenbrooke's Hospital",
#  'Basildon University Hospital',
#  'Blackpool Victoria Hospital',
#  'Bradford and Airedale SU',
#  'Bronglais Hospital',
#  'Broomfield Hospital',
#  'Calderdale Royal Hospital',
#  'Charing Cross Hospital HASU',
#  'Chesterfield Royal',
#  'Colchester General Hospital',
#  'Countess of Chester Hospital',
#  'Cumberland Infirmary',
#  'Darent Valley Hospital',
#  'Derriford Hospital',
#  'Doncaster Royal Infirmary',
#  'Dorset County Hospital',
#  'East Surrey Hospital',
#  'Eastbourne District General Hospital',
#  'Epsom Hospital',
#  'Fairfield General Hospital',
#  'Frimley Park Hospital',
#  'Furness General Hospital',
#  'Glan Clwyd District General Hospital',
#  'Gloucestershire Royal Hospital',
#  'Grange University Hospital',
#  'Great Western Hospital Swindon',
#  'Hereford County Hospital',
#  'Hull Royal Infirmary',
#  'Invicta Ward Kent and Canterbury Hospital ',
#  'Ipswich Hospital',
#  'James Cook University Hospital',
# ...

# %%
len(sam.globvars.included_teams)
# Out:
# 119

# %%
sam.globvars.excluded_teams
# Out:
# ['Princess Alexandra Hospital', 'Princess Royal Hospital Haywards Heath']
